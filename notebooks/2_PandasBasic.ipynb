# %% [markdown]
# # Installation

# %%
# !pip install pandas matplotlib openpyxl lxml
# Out:
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# # Reading Data

# %%
# pd.read<TAB>
data = pd.read_csv("https://raw.githubusercontent.com/bpampuch/1025/main/data/LoanData/train.csv")

# %% [markdown]
# ## Writing Data

# %%
# data.to<TAB>

# %% [markdown]
# # First look

# %%
data.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
data.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
data.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# ## Subsetting DataFrame

# %%
data[["ApplicantIncome", "LoanAmount"]]
# Out:
#      ApplicantIncome  LoanAmount
# 0               5849         NaN
# 1               4583       128.0
# 2               3000        66.0
# 3               2583       120.0
# 4               6000       141.0
# ..               ...         ...
# 609             2900        71.0
# 610             4106        40.0
# 611             8072       253.0
# 612             7583       187.0
# 613             4583       133.0
#
# [614 rows x 2 columns]

# %% [markdown]
# ## Subsetting Series

# %%
data["LoanAmount"]
# Out:
# 0        NaN
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %% [markdown]
# ## Getting unique values from Series

# %%
data["Education"].unique()
# Out:
# array(['Graduate', 'Not Graduate'], dtype=object)

# %% [markdown]
# ## Particular value counts

# %%
data["Education"].value_counts()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: count, dtype: int64

# %% [markdown]
# ## Normalized value counts

# %%
data["Education"].value_counts(normalize=True)
# Out:
# Education
# Graduate        0.781759
# Not Graduate    0.218241
# Name: proportion, dtype: float64

# %% [markdown]
# # Filtering

# %%
data["LoanAmount"] > 100
# Out:
# 0      False
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 609    False
# 610    False
# 611     True
# 612     True
# 613     True
# Name: LoanAmount, Length: 614, dtype: bool

# %%
data[data["LoanAmount"] > 100]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 7    LP001014    Male     Yes         3+      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 607  LP002964    Male     Yes          2  Not Graduate            No
# 608  LP002974    Male     Yes          0      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Grouping

# %%
data.groupby("Gender")[["ApplicantIncome"]].agg(['mean', 'min', 'max'])
# Out:
#        ApplicantIncome
#                   mean  min    max
# Gender
# Female     4643.473214  210  19484
# Male       5446.460123  150  81000

# %% [markdown]
# # Recalculating

# %%
data["Loan_Amount_Term"]
# Out:
# 0      360.0
# 1      360.0
# 2      360.0
# 3      360.0
# 4      360.0
#        ...
# 609    360.0
# 610    180.0
# 611    360.0
# 612    360.0
# 613    360.0
# Name: Loan_Amount_Term, Length: 614, dtype: float64

# %%
data["Loan_Amount_Term"] / 12
# Out:
# 0      30.0
# 1      30.0
# 2      30.0
# 3      30.0
# 4      30.0
#        ...
# 609    30.0
# 610    15.0
# 611    30.0
# 612    30.0
# 613    30.0
# Name: Loan_Amount_Term, Length: 614, dtype: float64

# %% [markdown]
# ## Creating new columns

# %%
data["Load_Amount_In_Years"] = data["Loan_Amount_Term"] / 12
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Sorting

# %%
data.sort_values('ApplicantIncome', ascending=False)
# data.sort_values?
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 409  LP002317    Male     Yes         3+      Graduate            No
# 333  LP002101    Male     Yes          0      Graduate           NaN
# 171  LP001585     NaN     Yes         3+      Graduate            No
# 155  LP001536    Male     Yes         3+      Graduate            No
# 185  LP001640    Male     Yes          0      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 188  LP001644     NaN     Yes          0      Graduate           Yes
# 500  LP002603  Female      No          0      Graduate            No
# 600  LP002949  Female      No         3+      Graduate           NaN
# 468  LP002502  Female     Yes          2  Not Graduate           NaN
# 216  LP001722    Male     Yes          0      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# # Handling missing values

# %%
data.isna()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
data.isna().sum()
# Out:
# Loan_ID                  0
# Gender                  13
# Married                  3
# Dependents              15
# Education                0
# Self_Employed           32
# ApplicantIncome          0
# CoapplicantIncome        0
# LoanAmount              22
# Loan_Amount_Term        14
# Credit_History          50
# Property_Area            0
# Loan_Status              0
# Load_Amount_In_Years    14
# dtype: int64

# %% [markdown]
# ## Dropping rows with missing values in specific columns

# %%
data2 = data

data2.dropna(subset=['LoanAmount'])
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# Other ways to deal with missing values will be presented later

# %% [markdown]
# # Merging series

# %%
serie1 = data["Gender"]
serie2 = data["LoanAmount"]

# axis=1 is needed - otherwise rows will be added to serie1
pd.concat([serie1, serie2], axis=1)
# Out:
#      Gender  LoanAmount
# 0      Male         NaN
# 1      Male       128.0
# 2      Male        66.0
# 3      Male       120.0
# 4      Male       141.0
# ..      ...         ...
# 609  Female        71.0
# 610    Male        40.0
# 611    Male       253.0
# 612    Male       187.0
# 613  Female       133.0
#
# [614 rows x 2 columns]

# %% [markdown]
# # Plotting charts

# %%
data.hist(figsize=(12, 8))
# Out:
# array([[<Axes: title={'center': 'ApplicantIncome'}>,
#         <Axes: title={'center': 'CoapplicantIncome'}>],
#        [<Axes: title={'center': 'LoanAmount'}>,
#         <Axes: title={'center': 'Loan_Amount_Term'}>],
#        [<Axes: title={'center': 'Credit_History'}>,
#         <Axes: title={'center': 'Load_Amount_In_Years'}>]], dtype=object)
